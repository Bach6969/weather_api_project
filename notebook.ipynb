# %%
baseurl = "http://api.weatherapi.com/v1"
bach_key = "1"

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
baseurl = f"http://api.weatherapi.com/v1/current.json?key={bach_key}&q=McKee"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Mckee',
#   'region': 'Georgia',
#   'country': 'United States of America',
#   'lat': 34.4597,
#   'lon': -84.1419,
#   'tz_id': 'America/New_York',
#   'localtime_epoch': 1777217036,
#   'localtime': '2026-04-26 11:23'},
#  'current': {'last_updated_epoch': 1777216500,
#   'last_updated': '2026-04-26 11:15',
#   'temp_c': 21.1,
#   'temp_f': 70.0,
#   'is_day': 1,
#   'condition': {'text': 'Partly Cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 2.2,
#   'wind_kph': 3.6,
#   'wind_degree': 150,
#   'wind_dir': 'SSE',
#   'pressure_mb': 1015.0,
#   'pressure_in': 29.96,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 66,
#   'cloud': 0,
#   'feelslike_c': 21.1,
#   'feelslike_f': 70.0,
#   'windchill_c': 20.6,
#   'windchill_f': 69.1,
#   'heatindex_c': 22.8,
#   'heatindex_f': 73.0,
#   'dewpoint_c': 14.7,
#   'dewpoint_f': 58.5,
#   'vis_km': 13.0,
#   'vis_miles': 8.0,
#   'uv': 4.8,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, wind_mph, humidity
# Out:
# (70.0, 2.2, 66)

# %%
def get_weather(city):
    baseurl = f"http://api.weatherapi.com/v1/current.json?key={bach_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']
        return temp_f, wind_mph, humidity

        print(f"Weather in {city}: {temp_f} F, {wind_mph} mph, {humidity}% humidity")
    else:
        print(f"Error: {response.status_code}")
        return None

# %%
get_weather("Portland")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_weather("Portland")
#
# Cell In[13], line 3, in get_weather(city)
#       1 def get_weather(city):
#       2     baseurl = f"http://api.weatherapi.com/v1/current.json?key={bach_key}&q={city}"
# ----> 3     response = requests.get(url)
#       4     if response.status_code == 200:
#       5         data = response.json()
#       6         current = data['current']
#
# NameError: name 'url' is not defined

# %%
cities = ["Portland", "Seattle", "San Francisco", "Denver", "Chicago"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={bach_key}&q={city}"
    response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    weather_data.append({
        "city": data['location']['name'],
        "temp_f": data['current']['temp_f'],
        "wind_mph": data['current']['wind_mph'],
        "humidity": data['current']['humidity'],
        "condition": data['current']['condition']['text']
    })
else:    print(f"Error: {response.status_code}")

# %%
weather_data
# Out:
# [{'city': 'Chicago',
#   'temp_f': 51.1,
#   'wind_mph': 6.9,
#   'humidity': 79,
#   'condition': 'Overcast'}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#       city  temp_f  wind_mph  humidity condition
# 0  Chicago    51.1       6.9        79  Overcast

# %%
weather_df.to_csv("weather_data.csv", index=False)

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
api_key = "1"
baseurl = "http://api.weatherapi.com/v1/"
# f"http//api.weatherapi.com/v1/current.json?key={api_key}&q=[city]"
city="Louisville"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1777223412,
#   'localtime': '2026-04-26 13:10'},
#  'current': {'last_updated_epoch': 1777222800,
#   'last_updated': '2026-04-26 13:00',
#   'temp_c': 12.8,
#   'temp_f': 55.0,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 6.3,
#   'wind_kph': 10.1,
#   'wind_degree': 64,
#   'wind_dir': 'ENE',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.05,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 86,
#   'cloud': 100,
#   'feelslike_c': 12.0,
#   'feelslike_f': 53.5,
#   'windchill_c': 22.6,
#   'windchill_f': 72.7,
#   'heatindex_c': 23.6,
#   'heatindex_f': 74.6,
#   'dewpoint_c': 14.7,
#   'dewpoint_f': 58.5,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
# ...

# %%
forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']

# %%
forecast_3_days_summary = []
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']} F = {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['2026-04-26: High 82.9 F = Sunny',
#  '2026-04-27: High 78.9 F = Patchy rain nearby',
#  '2026-04-28: High 75.7 F = Heavy rain']
